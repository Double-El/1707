# %%
# hit the target

import turtle as t
import random

def turn_up():
    t.left(2)
    
def turn_down():
    t.right(2)
    
def fire():
    angle = t.heading()
    while t.ycor() > 0:
        t.forward(15)
        t.right(5)
    
    distance = t.distance(target, 0)
    t.sety(random.randint(10,100))
    if distance < 20:
        t.color("blue")
        t.write("Hit", False, "center", ("", 15))
    else:
        t.color("red")
        t.write("Miss", False, "center", ("", 15))
    t.color("black")
    t.goto(-200, 10)
    t.setheading(angle)
    
def blank():
    t.clear()
    t.goto(-300, 0)
    t.down()
    t.goto(300, 0)

    target = random.randint(50, 150)
    t.pensize(3)
    t.color("green")
    t.up()
    t.goto(target - 25, 2)
    t.down()
    t.goto(target + 25, 2)

    t.color("black")
    t.up()
    t.goto(-200, 0)
    t.setheading(20)

t.shape("arrow")
    
t.goto(-300, 0)
t.down()
t.pensize(5)
t.goto(300, 0)

target = random.randint(50, 150)
t.pensize(5)
t.color("green")
t.up()
t.goto(target - 25, 2)
t.down()
t.goto(target + 25, 2)

t.color("black")
t.up()
t.goto(-200, 0)
t.setheading(20)

t.onkeypress(turn_up, "Up")
t.onkeypress(turn_down, "Down")
t.onkeypress(fire, "space")
t.onkeypress(blank, "Escape")

t.listen()
t.mainloop()
